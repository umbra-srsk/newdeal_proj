# %%
from selenium import webdriver
from pprint import pprint
from bs4 import BeautifulSoup
import urllib.request as req
import requests
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
url = 'https://www.tripadvisor.com/Attraction_Review-g294197-d1169465-Reviews-N_Seoul_Tower-Seoul.html'

driver = webdriver.Chrome()
driver.get(url)
time.sleep(2)

driver.find_element(By.XPATH, '/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[9]/div/div/div/section/section/div[1]/div/div[1]/div/div/div[2]/div/div/div[1]/div/button').send_keys(Keys.ENTER)
time.sleep(1)
driver.find_element(By.XPATH, '/html/body/div[5]/div/div[2]/div/div[2]/div/button[1]').send_keys(Keys.ENTER)
driver.find_element(By.XPATH, '/html/body/div[5]/div/div[3]/div/div[1]/button').send_keys(Keys.ENTER)
time.sleep(1)

data = []
j = 1
while(j < 7):
#for j in range(2, 4):
    j += 1
    for i in range(2, 12):

        try:
            if j == 2:
                review = driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[9]/div/div/div/section/section/div[1]/div/div[5]/div/div[{i}]/div/div/div[5]/div[1]/div').text
                data.append(review)
                time.sleep(1)
            else:
                review = driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[9]/div/div/div/section/section/div[1]/div/div[5]/div/div[{i}]/div/div/div[5]/div[1]/div/span').text
                data.append(review)
                time.sleep(1)
        except:
            continue

    try:
        driver.find_element(By.XPATH, '/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[9]/div/div/div/section/section/div[1]/div/div[5]/div/div[11]/div[1]/div/div[1]/div[2]/div/a').send_keys(Keys.ENTER)
        time.sleep(2)
    except:
        continue

    
    
driver.close()

# %%
pd.DataFrame(data)
# Out:
#                                                     0
# 0   We're not gonna complain about the hours it to...
# 1   We planned an afternoon visit. If you are hard...
# 2   The view is great but the 90 minutes que to lo...
# 3   Crazy long ques and crowds pushing and shoving...
# 4   Since in april and may weather is smokey and r...
# 5   We were here nearing sunset. The view of Seoul...
# 6   Do you want to waste your time waiting for a s...
# 7   The view is kind of nice but is not worth it\n...
# 8   The best time to visit the tower is before sun...
# 9   Nothing really impressed me in SK, this one, i...
# 10  I was not really interested in going to the to...
# 11  Just a line. Took my ticket around 7:30pm and ...
# 12  We arrived and my eyes almost popped out to se...
# 13  Long lines, upsells on pictures and other item...
# 14  We took the cable car to reach the Tower. We t...
# 15  Stupid cable car cannot handle the volume of v...
# 16  Go during the day. Night views aren't so great...
# 17  Crazy queue just to take the ride up to the to...
# 18  I went up on a misty night, and somehow I assu...
# 19  We started our visit in N Seoul Tower at 4pm i...
# 20  We are residents in Seoul since 4 years and we...
# 21  Access only by public transport : bus or by te...
# 22  We went there to have , as everyone, a nice vi...
# 23  I came by when it was a China long holiday per...
# 24  It's worth walking up the mountain as you will...
# 25  I have been to the tower in Osaka, Tokyo, Shan...
# 26  Went up by the cable car and waited for at lea...
# 27  caught a taxi to get up there to have a little...
# 28  Too many people! And very impolite people! Lon...
# 29  There are so many better things to do in Seoul...
# 30  Very crowded and expensive if you want to take...
# 31  You can actually walk to the base of the N Tow...
# 32  Skip Seoul Tower. We usually don’t write negat...
# 33  Travel up to seoul Tower by Cable car (8000 wo...
# 34  I just visited the tower and I did not like it...
# 35  The walk up to the tower was great with flower...
# 36  To avoid absolutely on week-end. The waiting t...
# 37  Payed to go up the seoul tower wife, one tear ...
# 38  Its one of the horrible place to visit in Seou...
# 39  From the beginning to the end is an ant line. ...
# 40  The walk up to the tower was great with flower...
# 41  To avoid absolutely on week-end. The waiting t...
# 42  Payed to go up the seoul tower wife, one tear ...
# 43  Its one of the horrible place to visit in Seou...
# 44  From the beginning to the end is an ant line. ...
