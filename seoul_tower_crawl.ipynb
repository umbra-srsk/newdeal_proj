# %%
from selenium import webdriver
from pprint import pprint
from bs4 import BeautifulSoup
import urllib.request as req
import requests
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
url = 'https://www.tripadvisor.co.kr/Attraction_Review-g294197-d1169465-Reviews-N_Seoul_Tower-Seoul.html'

driver = webdriver.Chrome()
driver.get(url)
time.sleep(2)

driver.find_element(By.XPATH, '/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[7]/div/div/div/section/section/div[1]/div/div[1]/div/div/div[2]/div/div/div[1]/div/button').send_keys(Keys.ENTER)
time.sleep(1)
driver.find_element(By.XPATH, '/html/body/div[5]/div/div[2]/div/div[2]/div/button[1]').send_keys(Keys.ENTER)
driver.find_element(By.XPATH, '/html/body/div[5]/div/div[3]/div/div[1]/button').send_keys(Keys.ENTER)
time.sleep(1)

data = []
j = 1
while(j < 4):
#for j in range(2, 4):
    j += 1
    for i in range(2, 12):

        try:
            if j == 2:
                review = driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[7]/div/div/div/section/section/div[1]/div/div[5]/div/div[{i}]/div/div/div[5]/div[1]/div/span').text
                data.append(review)
                time.sleep(1)
            else:
                review = driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[7]/div/div/div/section/section/div[1]/div/div[5]/div/div[{i}]/div/div/div[5]/div[1]/div/span/span').text
                data.append(review)
                time.sleep(1)
        except:
            continue

    try:
        driver.find_element(By.XPATH, f'/html/body/div[1]/main/div[1]/div[2]/div[2]/div[2]/div/div[1]/section[7]/div/div/div/section/section/div[1]/div/div[5]/div/div[12]/div[1]/div/div[2]/div/div[{j}]/a').send_keys(Keys.ENTER)
        time.sleep(2)
    except:
        continue

    
    
driver.close()

# %%
pd.DataFrame(data)
# Out:
#                                                     0
# 0   서울의 랜드마크, 주변의 산책로가 걷기 좋게 되어 있어 분위기가 좋다. 케이블카로 ...
# 1   여긴 특별한 공간이다.\n자주보지만 갈 일이 없는 그러니까 외지인들을 위한 공간이다...
# 2   뿌연하늘 외에는 볼게 정말 아무것도 없다. 야간에 가봐야 유리창에 반사된 형광등때문...
# 3   저는 정말 관심 가는 모양 타워 에서는 매력적인 (주). 하지만 서울을 무료로 이용...
# 4   만 대괄호),. 티켓에 내가 7:30 pm 물어볼 때까지 기다려야 한다: 없습니다!...
# 5   우리가 도착한 나는 줄 알고 있는 내 눈! 대기 시간이 오후 3시에 시작되고 도착해...
# 6   긴 줄, 상향 판매 및 기타 항목을 사진들. 수미요시 야외 전망대와 더러운 창문이 ...
# 7   저희는 케이블카 가 타워. 우리는 아름다운 태양 사진과 본 페이드. 있었는데 많은 ...
# 8   낮에 가. 야경이 훌륭하지 않 windows 매우 더러운 것, 좋은 사진 촬영 이 ...
# 9   미친 줄 그냥 타고 도쿄 타워, 특히 공휴일. 나는 설날 이 라 을 수 있었다. 제...
# 10  저희는 오후 4시에 방문 할 때는 n 서울 타워. 내 친구들과 나는 한 시간 이상 ...
# 11  서울에 있는 4 년 이후 매년 주민 하여 두 번이나 그 이상으로 타워. 좋은 장소에...
# 12  액세스 대중 교통: 버스 또는 telepheric. 비오는 날에 방문하며 다음으로 ...
# 13  같이 가는 것이 가치가 있는 산이 보이는 전망 좋은 서울 산 꼭대기. 하지만 올라가...
# 14  택시를 타면 이 좀 있었어요. 불행하게도 저를 잡아 왼쪽을 보면 케이블카 인입구. ...
# 15  너무 많은 사람이! 매우 무례한 사람들! 긴 줄을 구성할 수 있는 좋지 않습니다. ...
# ...
